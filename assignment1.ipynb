# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
arr = np.random.randn(10000, 10)

# %%
print(arr)
# Out:
# [[-0.45107273  1.04944839 -0.3530397  ...  0.10303562 -0.51424845
#    0.80827057]
#  [-0.49767804 -0.67483485 -0.59102125 ...  0.89877393 -0.21685719
#   -1.19868743]
#  [ 0.30610123 -1.90247343  1.26984887 ...  1.35183335 -1.10621966
#    1.63709318]
#  ...
#  [ 0.40180387 -1.47116706  2.38074667 ... -1.17238247 -0.53960211
#    0.09745443]
#  [ 0.73991401  0.54246304  0.18714602 ... -0.10021436 -0.38380913
#    1.41278364]
#  [-0.65175969 -0.24238481 -1.82432675 ...  0.87542414  0.6730564
#    0.36014622]]

# %%
df = pd.DataFrame(arr)

# %%
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.451073  1.049448 -0.353040 -1.037034 -0.495826 -0.714680  0.300589
# 1    -0.497678 -0.674835 -0.591021  1.316422 -2.162339  0.218881 -0.147588
# 2     0.306101 -1.902473  1.269849  1.440531  0.330912 -0.695424 -0.015737
# 3    -0.663512 -0.674476  0.519429  1.914200 -0.258434 -0.303812  0.648924
# 4    -0.620846 -0.026461  0.773716  1.693166  0.461193  1.378501  0.733550
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.795948  1.549341 -0.118442 -1.257685 -2.033843 -1.861898  1.609127
# 9996  1.660098 -0.414709 -0.808500 -1.814981 -0.186961 -0.106002  0.435848
# 9997  0.401804 -1.471167  2.380747 -0.902566 -0.055541 -0.056843  2.157770
# 9998  0.739914  0.542463  0.187146  0.012499 -0.172900  0.378945 -0.434187
# 9999 -0.651760 -0.242385 -1.824327 -0.259717 -0.955857 -0.378737 -0.071381
#
#              7         8         9
# ...

# %%
df.hist(0)
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %% [markdown]
# ### The maximum value lies between -1 to 0
# ### -3 and -2 have the value of 500

# %%
df.to_csv('newassignment', index=False)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\tanmay\\Assignment'

# %%
df= pd.read_csv('newassignment')

# %%
df
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              0  0.440464  0.293298 -0.336754 -0.567894 -0.175759  0.952635
# 1              1  0.135430 -0.820094  0.314890 -1.421364  0.750783 -0.261856
# 2              2  0.711613  0.728585 -0.728167  0.426999  1.084237 -0.460541
# 3              3  0.944987  0.293389 -0.369991  0.197909  1.152527  1.159866
# 4              4 -0.219499 -1.202340 -0.195926  0.185673  0.405591 -1.186859
# ...          ...       ...       ...       ...       ...       ...       ...
# 9995        9995  0.284019 -0.206094 -0.699284  0.900691  2.280652 -0.764413
# 9996        9996 -0.298235  1.490720 -1.250961 -0.044303  1.264171  0.198258
# 9997        9997 -0.845694  0.233119 -0.830095  0.535924  0.388385  0.052752
# 9998        9998 -1.555218  1.112270 -1.165001  0.671196  0.873373  0.204012
# 9999        9999 -0.859235  1.254635  1.069949 -1.035342 -0.073691 -1.058520
#
#              6         7         8         9
# ...

# %%
class MyClass:

    def __init__(self, arr):
        self.my_dataframe = arr

a = MyClass(arr)
b = MyClass(arr)

# %%
import random
num= random.randint(10,20)
print(num)
# Out:
# 11

# %%
df.to_csv('newassignment', index=False)
